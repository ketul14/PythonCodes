# %%
! pip install --upgrade terality
# Out:
# ...
#   Using cached requests-2.27.1-py2.py3-none-any.whl (63 kB)
# ...
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.42.1
#     Uninstalling tqdm-4.42.1:
#       Successfully uninstalled tqdm-4.42.1
#   Attempting uninstall: requests
#     Found existing installation: requests 2.22.0
#     Uninstalling requests-2.22.0:
#       Successfully uninstalled requests-2.22.0
# ...
# ERROR: conda 4.10.0 requires ruamel_yaml_conda>=0.11.14, which is not installed.
# ERROR: pycaret 2.3.0 has requirement numpy==1.19.5, but you'll have numpy 1.21.5 which is incompatible.
# ERROR: pycaret 2.3.0 has requirement scikit-learn==0.23.2, but you'll have scikit-learn 0.24.1 which is incompatible.
# ERROR: pycaret 2.3.0 has requirement scipy<=1.5.4, but you'll have scipy 1.6.2 which is incompatible.

# %%
import terality as te
te.configure(
    email="ksboghara@gmail.com",
    api_key="tla_Kiv78aqh6CtxvJ0wOP9lbG9CCONdhfWD3cXglZ1DUDgsGUBnhGEfgKuUDE6Z02R9Wa"
)
# Out:
# WARNING:terality:A Terality configuration file is already present at C:\Users\Ketulp\.terality\config.json.
# WARNING:terality:A Terality credentials file is already present at C:\Users\Ketulp\.terality\credentials.json.
# INFO:terality:Terality account successfully configured on this system.

# %%
import terality as te

# You can now process your data with Terality:
df = te.read_csv("india-covid-data.csv")
# Out:
# india-covid-data.csv: 100%|███████████████████████████████████████████████████████| 1.92k/1.92k [00:01<00:00, 1.87kB/s]

# %%
df
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar         7546       5        7412
# 1                             Andhra Pradesh      1983721   19549     1950623
# 2                          Arunachal Pradesh        50372    2606       47520
# 3                                      Assam       575220   11096      558720
# 4                                      Bihar       725235     286      715303
# 5                                 Chandigarh        61984      27       61146
# 6                               Chhattisgarh      1003244    1700      988004
# 7   Dadra and Nagar Haveli and Daman and Diu        10653       6       10643
# 8                                      Delhi      1436800     498     1411235
# 9                                        Goa       171944     896      167884
# 10                                   Gujarat       825064     209      814778
# ...

# %%
import pandas as pd
df_pd = pd.read_csv("india-covid-data.csv")

# %%
df_pd
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar         7546       5        7412
# 1                             Andhra Pradesh      1983721   19549     1950623
# 2                          Arunachal Pradesh        50372    2606       47520
# 3                                      Assam       575220   11096      558720
# 4                                      Bihar       725235     286      715303
# 5                                 Chandigarh        61984      27       61146
# 6                               Chhattisgarh      1003244    1700      988004
# 7   Dadra and Nagar Haveli and Daman and Diu        10653       6       10643
# 8                                      Delhi      1436800     498     1411235
# 9                                        Goa       171944     896      167884
# 10                                   Gujarat       825064     209      814778
# ...
